# %%
r"""
-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
Reduced order model for a thermal system of electronic circuit developed via Lumped Parameter Linear Superposition (LPLSP) method. 
This code maps the heat generated at source (Watt) within the system to the temperature reponse (degree C) at any location within the system. 
It works seamlessly for a system with many sources and many monitor points, which may be present on the source or away from the source.

This model works in two stages:
1. Training - In this stage, the algorithm learns various parameters that physically relate the heat dissipated at the source (input) to the temperature response at a monitor point (output). 
    1.1. This model reduces a thermal system to lumped parameters (thermal resistance [R] - physically represents a component's resistance to heat flow, thermal capacitance [C] - physically represents a component's ability to store heat, time constant [K] = 1/RC)
    1.2. It relates the heat loss in an electronic component (input power dissipation in Watts) to spatial temperature change (for example temperature within the component or on the case or at a location on the PCBA in degree C) using equation
                T_i(t) = T_0 + \sum_{j=1} ^{N} \sum_{m} \Delta(P_j(t)*R_ij)_{m} *(1-e^{-K_ij*(t-t_m)})
                where, j is the number of heat sources and m is the index of change of input
    1.3. The terms R_ij (thermal resistance matrix) and K_ij (time constant matrix) generally require several sequential simulations, where a unit input power (1W) is applied to each source and the temperature response of all the monitor points are measured. Then a superposition matrix is created.
    1.4. However, in this case instead of sequential simulations, a single transient simulation is run where all the heat sources are excited at the same time and all the temperature monitor points are measured. Then a parameter matrix for R,K that map output T to input P are estimated simultaneously.
    1.5. Once estimated, the parameter matrices R,K are saved.
    
2. Testing / Prediction - In this stage, the algorithm uses the saved parameters (representation of the full system) to predict temperature response for new input power dissipations. 

This approach is very efficient because it reduces not only the the time required to predict temperature of a thermal system for new unseen inputs, but also reduces the time required to create the reduced order model which is a major bottleneck for large systems.

Complete description of this approach is presented in the following papers:
a. Background of the method, derivation and case studies 
    * N. Padmanabhan, "A Transient Thermal Model for Power Electronics Systems," SoutheastCon 2024, Atlanta, GA, USA, 2024, pp. 1294-1299, doi: 10.1109/SoutheastCon52093.2024.10500091.
    * Padmanabhan, N., "A Scalable Approach for Transient Thermal Modeling of Automotive Power Electronics," SAE Technical Paper Series, January 1, 2025, https://doi.org/10.4271/2025-01-5073.

b. Ensemble parameter estimation method, algorithm and case studies
    * Padmanabhan, N., "Rapid Modeling of Transient Thermal Systems through Ensemble Parameter Estimation Applied to the Lumped Parameter Linear Superposition Method," SAE Technical Paper Series, January 1, 2026, https://doi.org/10.4271/2026-01-5034.

This approach is generally applicable to any thermal system where conduction and convection modes dominate the heat transfer. However, extension to other systems will require careful review of the system (sources and sinks), units of heat generation, temperature response
and the dominant modes of heat transfer. While this approach can be expanded to non-linear convection (convection with variable flow velocities) and radiation, this code as is does not model these cases accurately. A separate code for the non-linear cases
will be posted.

SUMMARY OF THE CODE: 
This script identifies thermal coupling parameters between multiple power sources and multiple temperature sensors.

Model:
    Temperature = Sum of first-order thermal responses to input power changes.

Parameters estimated:
    R : thermal resistance matrix
    K : time constant matrix

Optimizer:
    scipy.optimize.least_squares()

Input file:
    Training.xlsx

    Format: Training data arranged in columns labeled t, P_j, T_i

Output file:
    parameters_rank_reduced.xlsx
"""
# STAGE 1 - PARAMETER ESTIMATION 

import numpy as np
from numba import njit
import pandas as pd
from scipy.optimize import least_squares
import time

#-------------------------------------------------------------------------------------------------------------------
# Predict temperature for one monitor point 
@njit(cache=True, fastmath=True)
def temperature_model(P, t, R_row, K_row, T0):
    """
    Parameters:
    P: ndarray(n_inputs, t_len) - Input power dissipation (W)
    t: ndarray(t_len,) - Time vector (s)
    R_row: ndarray(n_inputs,) - Thermal resistance coupling coefficients between each source and monitor points
    K_row: ndarray(n_inputs,) - Time constant coupling coefficients between each source and monitor points
    T_0: float - Ambient or reference temperature

    Output:
    Predicted temperature profile - T_0 + T_out: ndarray(t_len,)
    """
    n_inputs, t_len = P.shape
    T_out = np.zeros(t_len)

    # Process contribution from each power source 
    for j in range(n_inputs):
        Rj = R_row[j]
        Kj = K_row[j]

        # Create a local copy because we modify the first sample. The first sample is forced to zero as the initial value is not interpreted as a temperature step. 
        Pj = P[j].copy()
        Pj[0] = 0.0

        # Detect indices where the input power changes. It is at these indices where add a new summation of delta T. If the power is constant, the temperature curve has a first order response, if it varies then we have a summation of several
        # first order responses.
        idx_list = []
        for k in range(1, t_len):
            if Pj[k] != Pj[k-1]:
                idx_list.append(k)
        
        if len(idx_list) == 0:
            continue

        # Convert power to temperature response
        TC = Pj * Rj

        # Add the temperature response from every detected index change
        for idx in idx_list:
            delta = TC[idx] - TC[idx - 1]   # Magnitude of step 
            t0 = t[idx - 1]                 # time index where the input changes

            dt = t[idx:t_len] - t0          # time elapsed since index change occured

            # First order response - LPLSP. Applied to all future time points at the same time (vectorized computation)
            T_out[idx:t_len] += delta * (1 - np.exp(-Kj * dt))

    return T0 + T_out
#-------------------------------------------------------------------------------------------------------------------
# Residual Function 
# Compute sum of square error between temperature measured from the simulation (T_meas) and temperature predicted by the model (T_pred)
# and find the parameters that minimize the SSE.
#
# theta ->  build R,K matrices -> predict T_pred -> compare with T_meas -> compute SSE -> minimize SSE
# over all temperatures and time points.

def residuals(theta, t, P, T_meas, T0):
    N = P.shape[0]
    NN = N*N

    R = theta[:NN].reshape(N, N)
    K = theta[NN:].reshape(N, N)

    T_pred = np.zeros_like(T_meas)

    for i in range(N):
        T_pred[i] = temperature_model(P, t, R[i], K[i], T0)

    return (T_pred - T_meas).ravel()


# MAIN TRAINING SCRIPT FOR PARAMETER ESTIMATION

# 1. Load training data
# 2. Build power and temperature arrays
# 3. Define optimization settings
# 4. Estimate R and K matrices
# 5. Save identified parameters

if __name__ == "__main__":
    
    df = pd.read_excel("Training.xlsx")

    # Automatic identification of time vector, temperature columns, power columns. It is recommended the training file Training.xlsx has headers t, T_1, T_2, T_3 ..., P_1, P_2, P_3 etc.
    t = df["t"].values
    P_cols = [col for col in df.columns if col.startswith("P")]
    T_cols = [col for col in df.columns if col.startswith("T")]
    
    # Number of sources
    N = len(P_cols)
    
    # Power input array P : shape (N, T)
    P = np.vstack([df[col].values for col in P_cols])
    
    # Measured temperatures T_meas : shape (N, T)
    T_meas = np.vstack([df[col].values for col in T_cols])
    
    T0 = 20.0   # Initial temperature

    # Initial guess of 1 is used for all parameters 
    theta0 = np.ones(2 * N * N)
    
    
    # OPTIMIZATION
    
    print("\n Start Optimization")
    # Measure computation time
    start = time.time()

    # Methods - trf (trust reflective  / dogbox / lm - While all methods work, trf is observed to be most effective and allows usage of bounds. 
    # https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.least_squares.html
    
    result = least_squares(
        residuals,
        theta0,
        args=(t, P, T_meas, T0),
        method="trf",      # recommended after your tests
        max_nfev=10000,
        verbose=2
    )
    
    theta_est = result.x
    
    print("\n Optimization complete in %.2f s" % (time.time() - start))
    
    # EXTRACT FINAL MATRICES
    
    NN = N * N
    R_est = theta_est[:NN].reshape(N, N)
    K_est = theta_est[NN:].reshape(N, N)
    
    for i in range(N):
        for j in range(N):
            print(f"R{i+1}{j+1} = {R_est[i,j]:.6f};")
        print()
    
    for i in range(N):
        for j in range(N):
            print(f"K{i+1}{j+1} = {K_est[i,j]:.6f};")
        print()
    
    
    # SAVE PARAMETERS
    
    out_names = []
    out_values = []
    
    # Flatten R
    for i in range(N):
        for j in range(N):
            out_names.append(f"R{i+1}{j+1}")
            out_values.append(R_est[i, j])
    
    # Flatten K
    for i in range(N):
        for j in range(N):
            out_names.append(f"K{i+1}{j+1}")
            out_values.append(K_est[i, j])
    
    # Build DataFrame
    df_out = pd.DataFrame({
        "Parameter": out_names,
        "Value": out_values
    })
    
    # Write to Excel
    df_out.to_excel("param.xlsx", index=False)
# Out:
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.0250e+05                                    8.34e+02
#        1              2         7.3471e+04      2.90e+04       8.49e+00       7.03e+02
#        2              3         3.1096e+04      4.24e+04       1.70e+01       4.41e+02
#        3              5         1.7617e+04      1.35e+04       8.49e+00       3.37e+03
#        4              8         1.6512e+04      1.10e+03       1.06e+00       3.03e+02
#        5              9         1.5145e+04      1.37e+03       1.06e+00       2.93e+02
#        6             10         1.2739e+04      2.41e+03       2.12e+00       3.51e+03
#        7             13         1.2452e+04      2.87e+02       2.65e-01       3.41e+02
#        8             14         1.2166e+04      2.86e+02       2.65e-01       1.12e+03
#        9             15         1.1691e+04      4.75e+02       5.30e-01       9.57e+02
#       10             16         1.1134e+04      5.57e+02       5.30e-01       2.48e+02
#       11             17         1.0046e+04      1.09e+03       1.06e+00       1.03e+03
#       12             19         9.6354e+03      4.11e+02       5.30e-01       9.87e+02
#       13             20         9.2023e+03      4.33e+02       5.30e-01       1.31e+03
#       14             21         8.8168e+03      3.86e+02       5.30e-01       3.28e+02
#       15             22         8.3185e+03      4.98e+02       5.30e-01       5.20e+02
#       16             23         7.6513e+03      6.67e+02       1.06e+00       5.45e+03
#       17             25         7.4444e+03      2.07e+02       2.65e-01       1.32e+03
#       18             26         7.3763e+03      6.82e+01       6.63e-02       4.07e+02
#       19             27         7.3157e+03      6.06e+01       6.63e-02       2.72e+02
#       20             28         7.2118e+03      1.04e+02       1.33e-01       4.80e+02
#       21             29         7.0239e+03      1.88e+02       2.65e-01       3.80e+02
#       22             31         6.9160e+03      1.08e+02       1.33e-01       1.96e+02
#       23             32         6.7166e+03      1.99e+02       2.65e-01       1.93e+02
#       24             33         6.3473e+03      3.69e+02       5.30e-01       5.55e+02
#       25             35         6.3233e+03      2.40e+01       2.65e-01       6.34e+03
#       26             36         6.1936e+03      1.30e+02       6.63e-02       4.50e+02
#       27             37         6.1427e+03      5.09e+01       6.63e-02       2.55e+02
#       28             38         6.0481e+03      9.47e+01       1.33e-01       1.79e+02
#       29             39         5.8777e+03      1.70e+02       2.65e-01       9.45e+02
#       30             41         5.8189e+03      5.88e+01       1.33e-01       3.97e+02
#       31             42         5.7301e+03      8.87e+01       1.33e-01       2.54e+02
#       32             43         5.5902e+03      1.40e+02       2.65e-01       1.17e+03
#       33             45         5.5187e+03      7.15e+01       1.33e-01       3.97e+02
#       34             46         5.4405e+03      7.81e+01       1.33e-01       3.57e+02
#       35             48         5.3965e+03      4.40e+01       6.63e-02       1.68e+02
#       36             49         5.3127e+03      8.38e+01       1.33e-01       1.65e+02
#       37             50         5.1484e+03      1.64e+02       2.65e-01       1.62e+02
#       38             51         4.8511e+03      2.97e+02       5.30e-01       8.83e+02
#       39             54         4.8104e+03      4.07e+01       6.63e-02       1.53e+02
#       40             55         4.7719e+03      3.85e+01       6.63e-02       1.54e+02
#       41             56         4.6974e+03      7.45e+01       1.33e-01       1.93e+02
#       42             57         4.6770e+03      2.04e+01       2.65e-01       6.98e+03
#       43             58         4.5562e+03      1.21e+02       6.63e-02       3.03e+02
#       44             59         4.5173e+03      3.89e+01       6.63e-02       2.74e+02
#       45             60         4.4590e+03      5.83e+01       1.33e-01       4.76e+02
#       46             61         4.4401e+03      1.89e+01       1.33e-01       2.90e+03
#       47             62         4.3966e+03      4.35e+01       3.31e-02       2.52e+02
#       48             63         4.3774e+03      1.92e+01       3.31e-02       2.06e+02
#       49             64         4.3411e+03      3.63e+01       6.63e-02       1.44e+02
#       50             65         4.2705e+03      7.07e+01       1.33e-01       1.42e+02
#       51             66         4.1331e+03      1.37e+02       2.65e-01       2.59e+02
#       52             68         4.0788e+03      5.43e+01       1.33e-01       4.82e+02
#       53             70         4.0584e+03      2.04e+01       3.31e-02       2.30e+02
#       54             71         4.0278e+03      3.06e+01       6.63e-02       4.07e+02
#       55             72         3.9857e+03      4.21e+01       1.33e-01       7.89e+02
#       56             73         3.9738e+03      1.19e+01       1.33e-01       2.96e+03
#       57             74         3.9307e+03      4.30e+01       3.31e-02       2.89e+02
#       58             75         3.9122e+03      1.85e+01       3.31e-02       2.46e+02
#       59             76         3.8789e+03      3.33e+01       6.63e-02       1.33e+02
#       60             77         3.8146e+03      6.43e+01       1.33e-01       1.31e+02
#       61             78         3.6981e+03      1.16e+02       2.65e-01       6.43e+02
#       62             81         3.6802e+03      1.80e+01       3.31e-02       1.27e+02
#       63             82         3.6647e+03      1.54e+01       3.31e-02       1.28e+02
#       64             83         3.6341e+03      3.06e+01       6.63e-02       1.26e+02
#       65             84         3.5771e+03      5.70e+01       1.33e-01       5.19e+02
#       66             86         3.5572e+03      1.99e+01       6.63e-02       3.67e+02
#       67             87         3.5337e+03      2.35e+01       6.63e-02       6.20e+02
#       68             88         3.5148e+03      1.89e+01       6.63e-02       3.77e+02
#       69             89         3.4909e+03      2.39e+01       6.63e-02       6.01e+02
#       70             90         3.4724e+03      1.85e+01       6.63e-02       3.75e+02
#       71             91         3.4491e+03      2.33e+01       6.63e-02       6.17e+02
#       72             92         3.4312e+03      1.79e+01       6.63e-02       3.78e+02
#       73             93         3.4083e+03      2.29e+01       6.63e-02       6.26e+02
#       74             94         3.3908e+03      1.74e+01       6.63e-02       3.79e+02
#       75             95         3.3684e+03      2.25e+01       6.63e-02       6.36e+02
#       76             96         3.3515e+03      1.69e+01       6.63e-02       3.81e+02
#       77             97         3.3294e+03      2.20e+01       6.63e-02       6.46e+02
#       78             98         3.3130e+03      1.64e+01       6.63e-02       3.82e+02
#       79             99         3.2914e+03      2.17e+01       6.63e-02       6.56e+02
#       80             100        3.2754e+03      1.59e+01       6.63e-02       3.84e+02
#       81             101        3.2542e+03      2.13e+01       6.63e-02       6.66e+02
#       82             102        3.2387e+03      1.55e+01       6.63e-02       3.85e+02
#       83             103        3.2178e+03      2.09e+01       6.63e-02       6.76e+02
#       84             104        3.2028e+03      1.50e+01       6.63e-02       3.86e+02
#       85             105        3.1823e+03      2.05e+01       6.63e-02       6.86e+02
#       86             106        3.1677e+03      1.46e+01       6.63e-02       3.87e+02
#       87             107        3.1475e+03      2.02e+01       6.63e-02       6.95e+02
#       88             108        3.1334e+03      1.42e+01       6.63e-02       3.88e+02
#       89             109        3.1136e+03      1.98e+01       6.63e-02       7.05e+02
#       90             110        3.0998e+03      1.38e+01       6.63e-02       3.89e+02
#       91             111        3.0803e+03      1.95e+01       6.63e-02       7.14e+02
#       92             112        3.0670e+03      1.34e+01       6.63e-02       4.00e+02
#       93             113        3.0478e+03      1.91e+01       6.63e-02       7.24e+02
#       94             114        3.0348e+03      1.30e+01       6.63e-02       4.12e+02
#       95             115        3.0160e+03      1.88e+01       6.63e-02       7.33e+02
#       96             116        3.0034e+03      1.26e+01       6.63e-02       4.23e+02
#       97             117        2.9849e+03      1.85e+01       6.63e-02       7.42e+02
#       98             118        2.9726e+03      1.23e+01       6.63e-02       4.35e+02
#       99             119        2.9544e+03      1.82e+01       6.63e-02       7.52e+02
#       100            120        2.9424e+03      1.20e+01       6.63e-02       4.46e+02
#       101            121        2.9245e+03      1.79e+01       6.63e-02       7.61e+02
#       102            122        2.9129e+03      1.16e+01       6.63e-02       4.57e+02
#       103            123        2.9031e+03      9.79e+00       1.66e-02       3.32e+02
#       104            124        2.8901e+03      1.30e+01       3.31e-02       1.07e+02
#       105            125        2.8664e+03      2.37e+01       6.63e-02       1.66e+02
#       106            127        2.8552e+03      1.13e+01       3.31e-02       1.89e+02
#       107            128        2.8360e+03      1.91e+01       6.63e-02       3.36e+02
#       108            129        2.8286e+03      7.38e+00       6.63e-02       1.29e+03
#       109            130        2.8155e+03      1.31e+01       1.66e-02       2.30e+02
#       110            131        2.8087e+03      6.86e+00       1.66e-02       1.45e+02
#       111            132        2.7965e+03      1.22e+01       3.31e-02       1.04e+02
#       112            133        2.7728e+03      2.37e+01       6.63e-02       1.58e+02
#       113            134        2.7522e+03      2.07e+01       1.33e-01       1.55e+03
#       114            136        2.7273e+03      2.48e+01       3.31e-02       3.64e+02
#       115            137        2.7153e+03      1.21e+01       3.31e-02       1.85e+02
#       116            138        2.6949e+03      2.04e+01       6.63e-02       2.68e+02
#       117            140        2.6842e+03      1.06e+01       3.31e-02       2.07e+02
#       118            141        2.6738e+03      1.04e+01       3.31e-02       1.73e+02
#       119            142        2.6599e+03      1.39e+01       6.63e-02       9.28e+02
#       120            143        2.6539e+03      5.97e+00       6.63e-02       6.99e+02
#       121            144        2.6430e+03      1.09e+01       1.66e-02       3.82e+02
#       122            145        2.6305e+03      1.25e+01       3.31e-02       9.92e+01
#       123            146        2.6193e+03      1.12e+01       3.31e-02       9.81e+01
#       124            147        2.6001e+03      1.92e+01       6.63e-02       4.98e+02
#       125            149        2.5911e+03      8.96e+00       3.31e-02       2.55e+02
#       126            150        2.5813e+03      9.80e+00       3.31e-02       2.81e+02
#       127            151        2.5720e+03      9.28e+00       3.31e-02       2.15e+02
#       128            152        2.5625e+03      9.53e+00       3.31e-02       2.79e+02
#       129            153        2.5534e+03      9.09e+00       3.31e-02       2.16e+02
#       130            154        2.5441e+03      9.34e+00       3.31e-02       2.86e+02
#       131            155        2.5352e+03      8.88e+00       3.31e-02       2.20e+02
#       132            156        2.5260e+03      9.15e+00       3.31e-02       2.94e+02
#       133            157        2.5174e+03      8.67e+00       3.31e-02       2.24e+02
#       134            158        2.5084e+03      8.97e+00       3.31e-02       3.01e+02
#       135            159        2.4999e+03      8.47e+00       3.31e-02       2.28e+02
#       136            160        2.4912e+03      8.79e+00       3.31e-02       3.09e+02
#       137            161        2.4829e+03      8.28e+00       3.31e-02       2.31e+02
#       138            162        2.4742e+03      8.63e+00       3.31e-02       3.15e+02
#       139            163        2.4661e+03      8.10e+00       3.31e-02       2.35e+02
#       140            164        2.4577e+03      8.48e+00       3.31e-02       3.21e+02
#       141            165        2.4497e+03      7.94e+00       3.31e-02       2.37e+02
#       142            166        2.4414e+03      8.34e+00       3.31e-02       3.27e+02
#       143            167        2.4336e+03      7.78e+00       3.31e-02       2.40e+02
#       144            168        2.4254e+03      8.21e+00       3.31e-02       3.33e+02
#       145            169        2.4178e+03      7.63e+00       3.31e-02       2.42e+02
#       146            170        2.4097e+03      8.08e+00       3.31e-02       3.38e+02
#       147            171        2.4022e+03      7.49e+00       3.31e-02       2.45e+02
#       148            172        2.3942e+03      7.95e+00       3.31e-02       3.43e+02
#       149            173        2.3869e+03      7.35e+00       3.31e-02       2.47e+02
#       150            174        2.3791e+03      7.83e+00       3.31e-02       3.48e+02
#       151            175        2.3718e+03      7.22e+00       3.31e-02       2.49e+02
#       152            176        2.3641e+03      7.72e+00       3.31e-02       3.52e+02
#       153            177        2.3570e+03      7.09e+00       3.31e-02       2.50e+02
#       154            178        2.3494e+03      7.60e+00       3.31e-02       3.57e+02
#       155            179        2.3425e+03      6.96e+00       3.31e-02       2.52e+02
#       156            180        2.3350e+03      7.49e+00       3.31e-02       3.62e+02
#       157            181        2.3281e+03      6.84e+00       3.31e-02       2.54e+02
#       158            182        2.3208e+03      7.38e+00       3.31e-02       3.66e+02
#       159            183        2.3140e+03      6.72e+00       3.31e-02       2.55e+02
#       160            184        2.3068e+03      7.27e+00       3.31e-02       3.70e+02
#       161            185        2.3002e+03      6.60e+00       3.31e-02       2.57e+02
#       162            186        2.2930e+03      7.17e+00       3.31e-02       3.74e+02
#       163            187        2.2865e+03      6.49e+00       3.31e-02       2.58e+02
#       164            188        2.2794e+03      7.07e+00       3.31e-02       3.78e+02
#       165            189        2.2731e+03      6.38e+00       3.31e-02       2.59e+02
#       166            190        2.2661e+03      6.97e+00       3.31e-02       3.82e+02
#       167            191        2.2598e+03      6.27e+00       3.31e-02       2.60e+02
#       168            192        2.2530e+03      6.87e+00       3.31e-02       3.86e+02
#       169            193        2.2468e+03      6.16e+00       3.31e-02       2.61e+02
#       170            194        2.2400e+03      6.77e+00       3.31e-02       3.90e+02
#       171            195        2.2340e+03      6.06e+00       3.31e-02       2.63e+02
#       172            196        2.2273e+03      6.68e+00       3.31e-02       3.94e+02
#       173            197        2.2214e+03      5.95e+00       3.31e-02       2.64e+02
#       174            198        2.2148e+03      6.58e+00       3.31e-02       3.98e+02
#       175            199        2.2089e+03      5.85e+00       3.31e-02       2.64e+02
#       176            200        2.2024e+03      6.49e+00       3.31e-02       4.01e+02
#       177            201        2.1967e+03      5.76e+00       3.31e-02       2.65e+02
#       178            202        2.1903e+03      6.40e+00       3.31e-02       4.05e+02
#       179            203        2.1846e+03      5.66e+00       3.31e-02       2.66e+02
#       180            204        2.1783e+03      6.32e+00       3.31e-02       4.08e+02
#       181            205        2.1727e+03      5.57e+00       3.31e-02       2.67e+02
#       182            206        2.1665e+03      6.23e+00       3.31e-02       4.12e+02
#       183            207        2.1610e+03      5.48e+00       3.31e-02       2.68e+02
#       184            208        2.1549e+03      6.15e+00       3.31e-02       4.15e+02
#       185            209        2.1495e+03      5.39e+00       3.31e-02       2.68e+02
#       186            210        2.1434e+03      6.07e+00       3.31e-02       4.19e+02
#       187            211        2.1381e+03      5.30e+00       3.31e-02       2.69e+02
#       188            212        2.1321e+03      5.99e+00       3.31e-02       4.22e+02
#       189            213        2.1269e+03      5.21e+00       3.31e-02       2.70e+02
#       190            214        2.1210e+03      5.91e+00       3.31e-02       4.25e+02
#       191            215        2.1159e+03      5.13e+00       3.31e-02       2.70e+02
#       192            216        2.1100e+03      5.83e+00       3.31e-02       4.28e+02
#       193            217        2.1050e+03      5.05e+00       3.31e-02       2.71e+02
#       194            218        2.0992e+03      5.76e+00       3.31e-02       4.31e+02
#       195            219        2.0943e+03      4.97e+00       3.31e-02       2.71e+02
#       196            220        2.0886e+03      5.68e+00       3.31e-02       4.35e+02
#       197            221        2.0837e+03      4.89e+00       3.31e-02       2.72e+02
#       198            222        2.0781e+03      5.61e+00       3.31e-02       4.38e+02
#       199            223        2.0733e+03      4.81e+00       3.31e-02       2.72e+02
#       200            224        2.0677e+03      5.54e+00       3.31e-02       4.41e+02
#       201            225        2.0630e+03      4.74e+00       3.31e-02       2.72e+02
#       202            226        2.0575e+03      5.47e+00       3.31e-02       4.44e+02
#       203            227        2.0529e+03      4.67e+00       3.31e-02       2.73e+02
#       204            228        2.0475e+03      5.40e+00       3.31e-02       4.47e+02
#       205            229        2.0429e+03      4.59e+00       3.31e-02       2.73e+02
#       206            230        2.0375e+03      5.33e+00       3.31e-02       4.49e+02
#       207            231        2.0330e+03      4.52e+00       3.31e-02       2.73e+02
#       208            232        2.0277e+03      5.26e+00       3.31e-02       4.52e+02
#       209            233        2.0233e+03      4.45e+00       3.31e-02       2.73e+02
#       210            234        2.0181e+03      5.20e+00       3.31e-02       4.55e+02
#       211            235        2.0137e+03      4.39e+00       3.31e-02       2.74e+02
#       212            236        2.0086e+03      5.14e+00       3.31e-02       4.58e+02
#       213            237        2.0043e+03      4.32e+00       3.31e-02       2.74e+02
#       214            238        1.9992e+03      5.07e+00       3.31e-02       4.61e+02
#       215            239        1.9949e+03      4.26e+00       3.31e-02       2.75e+02
#       216            240        1.9899e+03      5.01e+00       3.31e-02       4.63e+02
#       217            241        1.9857e+03      4.19e+00       3.31e-02       2.79e+02
#       218            242        1.9808e+03      4.95e+00       3.31e-02       4.66e+02
#       219            243        1.9766e+03      4.13e+00       3.31e-02       2.82e+02
#       220            244        1.9717e+03      4.89e+00       3.31e-02       4.69e+02
#       221            245        1.9677e+03      4.07e+00       3.31e-02       2.85e+02
#       222            246        1.9628e+03      4.83e+00       3.31e-02       4.71e+02
#       223            247        1.9588e+03      4.01e+00       3.31e-02       2.88e+02
#       224            248        1.9541e+03      4.78e+00       3.31e-02       4.74e+02
#       225            249        1.9501e+03      3.95e+00       3.31e-02       2.91e+02
#       226            250        1.9454e+03      4.72e+00       3.31e-02       4.77e+02
#       227            251        1.9415e+03      3.89e+00       3.31e-02       2.94e+02
#       228            252        1.9383e+03      3.21e+00       8.29e-03       1.88e+02
#       229            253        1.9345e+03      3.78e+00       1.66e-02       9.31e+01
#       230            254        1.9307e+03      3.80e+00       1.66e-02       7.38e+01
#       231            255        1.9237e+03      7.00e+00       3.31e-02       2.17e+02
#       232            257        1.9202e+03      3.47e+00       1.66e-02       1.13e+02
#       233            258        1.9166e+03      3.65e+00       1.66e-02       9.81e+01
#       234            259        1.9101e+03      6.54e+00       3.31e-02       1.68e+02
#       235            261        1.9064e+03      3.60e+00       1.66e-02       9.68e+01
#       236            262        1.9028e+03      3.65e+00       1.66e-02       7.42e+01
#       237            263        1.8963e+03      6.49e+00       3.31e-02       2.59e+02
#       238            265        1.8929e+03      3.42e+00       1.66e-02       1.18e+02
#       239            266        1.8893e+03      3.55e+00       1.66e-02       1.05e+02
#       240            267        1.8831e+03      6.20e+00       3.31e-02       1.78e+02
#       241            269        1.8796e+03      3.58e+00       1.66e-02       9.46e+01
#       242            270        1.8760e+03      3.56e+00       1.66e-02       7.52e+01
#       243            271        1.8698e+03      6.20e+00       3.31e-02       2.77e+02
#       244            273        1.8664e+03      3.36e+00       1.66e-02       1.20e+02
#       245            274        1.8630e+03      3.45e+00       1.66e-02       1.11e+02
#       246            275        1.8571e+03      5.84e+00       3.31e-02       1.91e+02
#       247            276        1.8549e+03      2.24e+00       3.31e-02       6.21e+02
#       248            277        1.8511e+03      3.81e+00       8.29e-03       1.60e+02
#       249            278        1.8489e+03      2.16e+00       8.29e-03       7.58e+01
#       250            279        1.8453e+03      3.63e+00       1.66e-02       7.04e+01
#       251            280        1.8385e+03      6.80e+00       3.31e-02       1.59e+02
#       252            282        1.8353e+03      3.18e+00       1.66e-02       1.07e+02
#       253            283        1.8320e+03      3.31e+00       1.66e-02       1.14e+02
#       254            284        1.8267e+03      5.31e+00       3.31e-02       2.26e+02
#       255            285        1.8249e+03      1.84e+00       3.31e-02       6.43e+02
#       256            286        1.8210e+03      3.90e+00       8.29e-03       1.68e+02
#       257            287        1.8188e+03      2.15e+00       8.29e-03       8.09e+01
#       258            288        1.8153e+03      3.52e+00       1.66e-02       6.91e+01
#       259            289        1.8089e+03      6.45e+00       3.31e-02       1.85e+02
#       260            291        1.8058e+03      3.05e+00       1.66e-02       1.15e+02
#       261            292        1.8026e+03      3.17e+00       1.66e-02       1.24e+02
#       262            293        1.7979e+03      4.78e+00       3.31e-02       2.56e+02
#       263            294        1.7962e+03      1.62e+00       3.31e-02       6.55e+02
#       264            295        1.7923e+03      3.94e+00       8.29e-03       1.71e+02
#       265            296        1.7902e+03      2.13e+00       8.29e-03       8.19e+01
#       266            297        1.7867e+03      3.42e+00       1.66e-02       6.79e+01
#       267            298        1.7806e+03      6.15e+00       3.31e-02       2.03e+02
#       268            300        1.7776e+03      2.95e+00       1.66e-02       1.19e+02
#       269            301        1.7746e+03      3.05e+00       1.66e-02       1.32e+02
#       270            302        1.7715e+03      3.04e+00       1.66e-02       1.05e+02
#       271            303        1.7685e+03      3.06e+00       1.66e-02       1.26e+02
#       272            304        1.7642e+03      4.32e+00       3.31e-02       2.81e+02
#       273            305        1.7628e+03      1.40e+00       3.31e-02       6.67e+02
#       274            306        1.7588e+03      3.97e+00       8.29e-03       1.73e+02
#       275            307        1.7567e+03      2.10e+00       8.29e-03       8.25e+01
#       276            308        1.7534e+03      3.31e+00       1.66e-02       6.65e+01
#       277            309        1.7476e+03      5.79e+00       3.31e-02       2.25e+02
#       278            311        1.7447e+03      2.86e+00       1.66e-02       1.22e+02
#       279            312        1.7418e+03      2.91e+00       1.66e-02       1.41e+02
#       280            313        1.7389e+03      2.88e+00       1.66e-02       1.11e+02
#       281            314        1.7361e+03      2.89e+00       1.66e-02       1.38e+02
#       282            315        1.7332e+03      2.86e+00       1.66e-02       1.11e+02
#       283            316        1.7303e+03      2.87e+00       1.66e-02       1.39e+02
#       284            317        1.7275e+03      2.83e+00       1.66e-02       1.12e+02
#       285            318        1.7247e+03      2.84e+00       1.66e-02       1.41e+02
#       286            319        1.7219e+03      2.80e+00       1.66e-02       1.13e+02
#       287            320        1.7190e+03      2.81e+00       1.66e-02       1.43e+02
#       288            321        1.7163e+03      2.77e+00       1.66e-02       1.14e+02
#       289            322        1.7135e+03      2.78e+00       1.66e-02       1.45e+02
#       290            323        1.7107e+03      2.74e+00       1.66e-02       1.15e+02
#       291            324        1.7080e+03      2.75e+00       1.66e-02       1.47e+02
#       292            325        1.7053e+03      2.71e+00       1.66e-02       1.17e+02
#       293            326        1.7026e+03      2.72e+00       1.66e-02       1.49e+02
#       294            327        1.6999e+03      2.68e+00       1.66e-02       1.18e+02
#       295            328        1.6972e+03      2.69e+00       1.66e-02       1.51e+02
#       296            329        1.6945e+03      2.66e+00       1.66e-02       1.19e+02
#       297            330        1.6919e+03      2.67e+00       1.66e-02       1.53e+02
#       298            331        1.6892e+03      2.63e+00       1.66e-02       1.20e+02
#       299            332        1.6866e+03      2.64e+00       1.66e-02       1.54e+02
#       300            333        1.6840e+03      2.60e+00       1.66e-02       1.21e+02
#       301            334        1.6814e+03      2.61e+00       1.66e-02       1.56e+02
#       302            335        1.6788e+03      2.57e+00       1.66e-02       1.22e+02
#       303            336        1.6762e+03      2.59e+00       1.66e-02       1.58e+02
#       304            337        1.6737e+03      2.55e+00       1.66e-02       1.22e+02
#       305            338        1.6711e+03      2.56e+00       1.66e-02       1.60e+02
#       306            339        1.6686e+03      2.52e+00       1.66e-02       1.23e+02
#       307            340        1.6661e+03      2.54e+00       1.66e-02       1.61e+02
#       308            341        1.6636e+03      2.49e+00       1.66e-02       1.24e+02
#       309            342        1.6611e+03      2.51e+00       1.66e-02       1.63e+02
#       310            343        1.6586e+03      2.47e+00       1.66e-02       1.25e+02
#       311            344        1.6561e+03      2.49e+00       1.66e-02       1.64e+02
#       312            345        1.6537e+03      2.44e+00       1.66e-02       1.26e+02
#       313            346        1.6512e+03      2.46e+00       1.66e-02       1.66e+02
#       314            347        1.6488e+03      2.42e+00       1.66e-02       1.26e+02
#       315            348        1.6464e+03      2.44e+00       1.66e-02       1.68e+02
#       316            349        1.6440e+03      2.39e+00       1.66e-02       1.27e+02
#       317            350        1.6415e+03      2.41e+00       1.66e-02       1.69e+02
#       318            351        1.6392e+03      2.37e+00       1.66e-02       1.28e+02
#       319            352        1.6368e+03      2.39e+00       1.66e-02       1.71e+02
#       320            353        1.6344e+03      2.35e+00       1.66e-02       1.28e+02
#       321            354        1.6321e+03      2.37e+00       1.66e-02       1.72e+02
#       322            355        1.6297e+03      2.32e+00       1.66e-02       1.29e+02
#       323            356        1.6274e+03      2.35e+00       1.66e-02       1.73e+02
#       324            357        1.6251e+03      2.30e+00       1.66e-02       1.30e+02
#       325            358        1.6228e+03      2.32e+00       1.66e-02       1.75e+02
#       326            359        1.6205e+03      2.28e+00       1.66e-02       1.30e+02
#       327            360        1.6182e+03      2.30e+00       1.66e-02       1.76e+02
#       328            361        1.6160e+03      2.25e+00       1.66e-02       1.31e+02
#       329            362        1.6137e+03      2.28e+00       1.66e-02       1.77e+02
#       330            363        1.6114e+03      2.23e+00       1.66e-02       1.31e+02
#       331            364        1.6092e+03      2.26e+00       1.66e-02       1.79e+02
#       332            365        1.6070e+03      2.21e+00       1.66e-02       1.32e+02
#       333            366        1.6047e+03      2.24e+00       1.66e-02       1.80e+02
#       334            367        1.6025e+03      2.19e+00       1.66e-02       1.32e+02
#       335            368        1.6003e+03      2.22e+00       1.66e-02       1.81e+02
#       336            369        1.5982e+03      2.17e+00       1.66e-02       1.33e+02
#       337            370        1.5960e+03      2.20e+00       1.66e-02       1.83e+02
#       338            371        1.5938e+03      2.15e+00       1.66e-02       1.33e+02
#       339            372        1.5916e+03      2.18e+00       1.66e-02       1.84e+02
#       340            373        1.5895e+03      2.13e+00       1.66e-02       1.34e+02
#       341            374        1.5874e+03      2.16e+00       1.66e-02       1.85e+02
#       342            375        1.5853e+03      2.11e+00       1.66e-02       1.34e+02
#       343            376        1.5831e+03      2.14e+00       1.66e-02       1.86e+02
#       344            377        1.5810e+03      2.09e+00       1.66e-02       1.35e+02
#       345            378        1.5789e+03      2.12e+00       1.66e-02       1.87e+02
#       346            379        1.5769e+03      2.07e+00       1.66e-02       1.35e+02
#       347            380        1.5748e+03      2.10e+00       1.66e-02       1.88e+02
#       348            381        1.5727e+03      2.05e+00       1.66e-02       1.35e+02
#       349            382        1.5706e+03      2.08e+00       1.66e-02       1.90e+02
#       350            383        1.5686e+03      2.03e+00       1.66e-02       1.36e+02
#       351            384        1.5666e+03      2.06e+00       1.66e-02       1.91e+02
#       352            385        1.5645e+03      2.01e+00       1.66e-02       1.36e+02
#       353            386        1.5625e+03      2.04e+00       1.66e-02       1.92e+02
#       354            387        1.5605e+03      1.99e+00       1.66e-02       1.36e+02
#       355            388        1.5585e+03      2.02e+00       1.66e-02       1.93e+02
#       356            389        1.5565e+03      1.97e+00       1.66e-02       1.37e+02
#       357            390        1.5545e+03      2.01e+00       1.66e-02       1.94e+02
#       358            391        1.5526e+03      1.95e+00       1.66e-02       1.37e+02
#       359            392        1.5506e+03      1.99e+00       1.66e-02       1.95e+02
#       360            393        1.5486e+03      1.93e+00       1.66e-02       1.37e+02
#       361            394        1.5467e+03      1.97e+00       1.66e-02       1.96e+02
#       362            395        1.5448e+03      1.92e+00       1.66e-02       1.38e+02
#       363            396        1.5428e+03      1.95e+00       1.66e-02       1.97e+02
#       364            397        1.5409e+03      1.90e+00       1.66e-02       1.38e+02
#       365            398        1.5390e+03      1.94e+00       1.66e-02       1.98e+02
#       366            399        1.5371e+03      1.88e+00       1.66e-02       1.38e+02
#       367            400        1.5352e+03      1.92e+00       1.66e-02       1.99e+02
#       368            401        1.5333e+03      1.86e+00       1.66e-02       1.38e+02
#       369            402        1.5314e+03      1.90e+00       1.66e-02       2.00e+02
#       370            403        1.5296e+03      1.85e+00       1.66e-02       1.39e+02
#       371            404        1.5277e+03      1.89e+00       1.66e-02       2.01e+02
#       372            405        1.5258e+03      1.83e+00       1.66e-02       1.39e+02
#       373            406        1.5240e+03      1.87e+00       1.66e-02       2.02e+02
#       374            407        1.5222e+03      1.81e+00       1.66e-02       1.39e+02
#       375            408        1.5203e+03      1.85e+00       1.66e-02       2.03e+02
#       376            409        1.5185e+03      1.80e+00       1.66e-02       1.39e+02
#       377            410        1.5167e+03      1.84e+00       1.66e-02       2.04e+02
#       378            411        1.5149e+03      1.78e+00       1.66e-02       1.39e+02
#       379            412        1.5131e+03      1.82e+00       1.66e-02       2.05e+02
#       380            413        1.5113e+03      1.77e+00       1.66e-02       1.40e+02
#       381            414        1.5095e+03      1.81e+00       1.66e-02       2.06e+02
#       382            415        1.5078e+03      1.75e+00       1.66e-02       1.40e+02
#       383            416        1.5060e+03      1.79e+00       1.66e-02       2.07e+02
#       384            417        1.5042e+03      1.73e+00       1.66e-02       1.40e+02
#       385            418        1.5024e+03      1.78e+00       1.66e-02       2.08e+02
#       386            419        1.5007e+03      1.72e+00       1.66e-02       1.40e+02
#       387            420        1.4990e+03      1.76e+00       1.66e-02       2.09e+02
#       388            421        1.4973e+03      1.70e+00       1.66e-02       1.40e+02
#       389            422        1.4955e+03      1.75e+00       1.66e-02       2.10e+02
#       390            423        1.4938e+03      1.69e+00       1.66e-02       1.40e+02
#       391            424        1.4921e+03      1.73e+00       1.66e-02       2.11e+02
#       392            425        1.4904e+03      1.67e+00       1.66e-02       1.41e+02
#       393            426        1.4887e+03      1.72e+00       1.66e-02       2.11e+02
#       394            427        1.4870e+03      1.66e+00       1.66e-02       1.41e+02
#       395            428        1.4853e+03      1.70e+00       1.66e-02       2.12e+02
#       396            429        1.4837e+03      1.64e+00       1.66e-02       1.41e+02
#       397            430        1.4820e+03      1.69e+00       1.66e-02       2.13e+02
#       398            431        1.4804e+03      1.63e+00       1.66e-02       1.41e+02
#       399            432        1.4787e+03      1.68e+00       1.66e-02       2.14e+02
#       400            433        1.4771e+03      1.62e+00       1.66e-02       1.41e+02
#       401            434        1.4754e+03      1.66e+00       1.66e-02       2.15e+02
#       402            435        1.4738e+03      1.60e+00       1.66e-02       1.42e+02
#       403            436        1.4722e+03      1.65e+00       1.66e-02       2.16e+02
#       404            437        1.4706e+03      1.59e+00       1.66e-02       1.43e+02
#       405            438        1.4690e+03      1.63e+00       1.66e-02       2.17e+02
#       406            439        1.4674e+03      1.57e+00       1.66e-02       1.43e+02
#       407            440        1.4658e+03      1.62e+00       1.66e-02       2.17e+02
#       408            441        1.4642e+03      1.56e+00       1.66e-02       1.44e+02
#       409            442        1.4626e+03      1.61e+00       1.66e-02       2.18e+02
#       410            443        1.4610e+03      1.55e+00       1.66e-02       1.45e+02
#       411            444        1.4594e+03      1.60e+00       1.66e-02       2.19e+02
#       412            445        1.4579e+03      1.53e+00       1.66e-02       1.46e+02
#       413            446        1.4563e+03      1.58e+00       1.66e-02       2.20e+02
#       414            447        1.4548e+03      1.52e+00       1.66e-02       1.47e+02
#       415            448        1.4532e+03      1.57e+00       1.66e-02       2.21e+02
#       416            449        1.4517e+03      1.51e+00       1.66e-02       1.48e+02
#       417            450        1.4502e+03      1.56e+00       1.66e-02       2.21e+02
#       418            451        1.4487e+03      1.50e+00       1.66e-02       1.48e+02
#       419            452        1.4471e+03      1.55e+00       1.66e-02       2.22e+02
#       420            453        1.4456e+03      1.48e+00       1.66e-02       1.49e+02
#       421            454        1.4441e+03      1.53e+00       1.66e-02       2.23e+02
#       422            455        1.4426e+03      1.47e+00       1.66e-02       1.50e+02
#       423            456        1.4411e+03      1.52e+00       1.66e-02       2.24e+02
#       424            457        1.4397e+03      1.46e+00       1.66e-02       1.51e+02
#       425            458        1.4382e+03      1.51e+00       1.66e-02       2.24e+02
#       426            459        1.4367e+03      1.45e+00       1.66e-02       1.52e+02
#       427            460        1.4352e+03      1.50e+00       1.66e-02       2.25e+02
#       428            461        1.4338e+03      1.43e+00       1.66e-02       1.53e+02
#       429            462        1.4323e+03      1.49e+00       1.66e-02       2.26e+02
#       430            463        1.4309e+03      1.42e+00       1.66e-02       1.53e+02
#       431            464        1.4294e+03      1.47e+00       1.66e-02       2.27e+02
#       432            465        1.4280e+03      1.41e+00       1.66e-02       1.54e+02
#       433            466        1.4265e+03      1.46e+00       1.66e-02       2.27e+02
#       434            467        1.4251e+03      1.40e+00       1.66e-02       1.55e+02
#       435            468        1.4237e+03      1.45e+00       1.66e-02       2.28e+02
#       436            469        1.4223e+03      1.39e+00       1.66e-02       1.56e+02
#       437            470        1.4208e+03      1.44e+00       1.66e-02       2.29e+02
#       438            471        1.4195e+03      1.38e+00       1.66e-02       1.57e+02
#       439            472        1.4180e+03      1.43e+00       1.66e-02       2.30e+02
#       440            473        1.4167e+03      1.37e+00       1.66e-02       1.57e+02
#       441            474        1.4153e+03      1.42e+00       1.66e-02       2.30e+02
#       442            475        1.4139e+03      1.35e+00       1.66e-02       1.58e+02
#       443            476        1.4125e+03      1.41e+00       1.66e-02       2.31e+02
#       444            477        1.4111e+03      1.34e+00       1.66e-02       1.59e+02
#       445            478        1.4097e+03      1.40e+00       1.66e-02       2.32e+02
#       446            479        1.4084e+03      1.33e+00       1.66e-02       1.60e+02
#       447            480        1.4070e+03      1.39e+00       1.66e-02       2.33e+02
#       448            481        1.4057e+03      1.32e+00       1.66e-02       1.61e+02
#       449            482        1.4043e+03      1.38e+00       1.66e-02       2.33e+02
#       450            483        1.4030e+03      1.31e+00       1.66e-02       1.61e+02
#       451            484        1.4017e+03      1.37e+00       1.66e-02       2.34e+02
#       452            485        1.4004e+03      1.30e+00       1.66e-02       1.62e+02
#       453            486        1.3990e+03      1.36e+00       1.66e-02       2.35e+02
#       454            487        1.3977e+03      1.29e+00       1.66e-02       1.63e+02
#       455            488        1.3964e+03      1.35e+00       1.66e-02       2.35e+02
#       456            489        1.3951e+03      1.28e+00       1.66e-02       1.64e+02
#       457            490        1.3937e+03      1.34e+00       1.66e-02       2.36e+02
#       458            491        1.3925e+03      1.27e+00       1.66e-02       1.65e+02
#       459            492        1.3912e+03      1.33e+00       1.66e-02       2.37e+02
#       460            493        1.3899e+03      1.26e+00       1.66e-02       1.65e+02
#       461            494        1.3886e+03      1.32e+00       1.66e-02       2.37e+02
#       462            495        1.3873e+03      1.25e+00       1.66e-02       1.66e+02
#       463            496        1.3860e+03      1.31e+00       1.66e-02       2.38e+02
#       464            497        1.3848e+03      1.24e+00       1.66e-02       1.67e+02
#       465            498        1.3835e+03      1.30e+00       1.66e-02       2.39e+02
#       466            499        1.3823e+03      1.23e+00       1.66e-02       1.68e+02
#       467            500        1.3810e+03      1.29e+00       1.66e-02       2.39e+02
#       468            501        1.3797e+03      1.22e+00       1.66e-02       1.68e+02
#       469            502        1.3785e+03      1.28e+00       1.66e-02       2.40e+02
#       470            503        1.3773e+03      1.21e+00       1.66e-02       1.69e+02
#       471            504        1.3760e+03      1.27e+00       1.66e-02       2.41e+02
#       472            505        1.3748e+03      1.20e+00       1.66e-02       1.70e+02
#       473            506        1.3735e+03      1.26e+00       1.66e-02       2.41e+02
#       474            507        1.3723e+03      1.19e+00       1.66e-02       1.71e+02
#       475            508        1.3711e+03      1.25e+00       1.66e-02       2.42e+02
#       476            509        1.3699e+03      1.18e+00       1.66e-02       1.71e+02
#       477            510        1.3687e+03      1.24e+00       1.66e-02       2.43e+02
#       478            511        1.3675e+03      1.17e+00       1.66e-02       1.72e+02
#       479            512        1.3663e+03      1.23e+00       1.66e-02       2.43e+02
#       480            513        1.3651e+03      1.16e+00       1.66e-02       1.73e+02
#       481            514        1.3639e+03      1.22e+00       1.66e-02       2.44e+02
#       482            515        1.3627e+03      1.16e+00       1.66e-02       1.74e+02
#       483            516        1.3615e+03      1.22e+00       1.66e-02       2.45e+02
#       484            517        1.3603e+03      1.15e+00       1.66e-02       1.74e+02
#       485            518        1.3591e+03      1.21e+00       1.66e-02       2.45e+02
#       486            519        1.3580e+03      1.14e+00       1.66e-02       1.75e+02
#       487            520        1.3568e+03      1.20e+00       1.66e-02       2.46e+02
#       488            521        1.3557e+03      1.13e+00       1.66e-02       1.76e+02
#       489            522        1.3545e+03      1.19e+00       1.66e-02       2.46e+02
#       490            523        1.3534e+03      1.12e+00       1.66e-02       1.77e+02
#       491            524        1.3522e+03      1.18e+00       1.66e-02       2.47e+02
#       492            525        1.3511e+03      1.11e+00       1.66e-02       1.77e+02
#       493            526        1.3499e+03      1.17e+00       1.66e-02       2.48e+02
#       494            527        1.3488e+03      1.10e+00       1.66e-02       1.78e+02
#       495            528        1.3476e+03      1.17e+00       1.66e-02       2.48e+02
#       496            529        1.3465e+03      1.10e+00       1.66e-02       1.79e+02
#       497            530        1.3454e+03      1.16e+00       1.66e-02       2.49e+02
#       498            531        1.3443e+03      1.09e+00       1.66e-02       1.80e+02
#       499            532        1.3431e+03      1.15e+00       1.66e-02       2.49e+02
#       500            533        1.3421e+03      1.08e+00       1.66e-02       1.80e+02
#       501            534        1.3409e+03      1.14e+00       1.66e-02       2.50e+02
#       502            535        1.3398e+03      1.07e+00       1.66e-02       1.81e+02
#       503            536        1.3387e+03      1.13e+00       1.66e-02       2.51e+02
#       504            537        1.3376e+03      1.06e+00       1.66e-02       1.82e+02
#       505            538        1.3365e+03      1.13e+00       1.66e-02       2.51e+02
#       506            539        1.3355e+03      1.06e+00       1.66e-02       1.82e+02
#       507            540        1.3346e+03      8.78e-01       4.14e-03       8.71e+01
#       508            541        1.3336e+03      9.68e-01       8.29e-03       5.48e+01
#       509            542        1.3326e+03      9.94e-01       8.29e-03       4.58e+01
#       510            543        1.3308e+03      1.80e+00       1.66e-02       1.18e+02
#       511            545        1.3299e+03      9.43e-01       8.29e-03       5.03e+01
#       512            546        1.3289e+03      9.74e-01       8.29e-03       4.61e+01
#       513            547        1.3272e+03      1.75e+00       1.66e-02       9.13e+01
#       514            549        1.3262e+03      9.55e-01       8.29e-03       5.37e+01
#       515            550        1.3252e+03      9.73e-01       8.29e-03       4.54e+01
#       516            551        1.3235e+03      1.74e+00       1.66e-02       1.25e+02
#       517            553        1.3226e+03      9.37e-01       8.29e-03       5.02e+01
#       518            554        1.3216e+03      9.59e-01       8.29e-03       4.71e+01
#       519            555        1.3199e+03      1.70e+00       1.66e-02       9.51e+01
#       520            557        1.3189e+03      9.48e-01       8.29e-03       5.38e+01
#       521            558        1.3180e+03      9.58e-01       8.29e-03       4.49e+01
#       522            559        1.3163e+03      1.69e+00       1.66e-02       1.29e+02
#       523            561        1.3154e+03      9.29e-01       8.29e-03       5.03e+01
#       524            562        1.3144e+03      9.45e-01       8.29e-03       4.81e+01
#       525            563        1.3128e+03      1.65e+00       1.66e-02       9.92e+01
# ...
#      9548           9841        4.0175e+02      2.93e-02       2.07e-03       2.67e+01
#      9549           9842        4.0172e+02      2.88e-02       2.07e-03       2.72e+01
#      9550           9843        4.0169e+02      2.92e-02       2.07e-03       2.67e+01
#      9551           9844        4.0166e+02      2.88e-02       2.07e-03       2.72e+01
#      9552           9845        4.0163e+02      2.92e-02       2.07e-03       2.67e+01
#      9553           9846        4.0161e+02      2.88e-02       2.07e-03       2.72e+01
#      9554           9847        4.0158e+02      2.92e-02       2.07e-03       2.67e+01
#      9555           9848        4.0155e+02      2.88e-02       2.07e-03       2.72e+01
#      9556           9849        4.0152e+02      2.92e-02       2.07e-03       2.67e+01
#      9557           9850        4.0149e+02      2.88e-02       2.07e-03       2.73e+01
#      9558           9851        4.0146e+02      2.92e-02       2.07e-03       2.67e+01
#      9559           9852        4.0143e+02      2.87e-02       2.07e-03       2.73e+01
#      9560           9853        4.0140e+02      2.92e-02       2.07e-03       2.67e+01
#      9561           9854        4.0137e+02      2.87e-02       2.07e-03       2.73e+01
#      9562           9855        4.0134e+02      2.92e-02       2.07e-03       2.67e+01
#      9563           9856        4.0132e+02      2.87e-02       2.07e-03       2.73e+01
#      9564           9857        4.0129e+02      2.92e-02       2.07e-03       2.67e+01
#      9565           9858        4.0126e+02      2.87e-02       2.07e-03       2.73e+01
#      9566           9859        4.0123e+02      2.92e-02       2.07e-03       2.68e+01
#      9567           9860        4.0120e+02      2.87e-02       2.07e-03       2.73e+01
#      9568           9861        4.0117e+02      2.92e-02       2.07e-03       2.68e+01
#      9569           9862        4.0114e+02      2.87e-02       2.07e-03       2.73e+01
#      9570           9863        4.0111e+02      2.92e-02       2.07e-03       2.68e+01
#      9571           9864        4.0108e+02      2.87e-02       2.07e-03       2.73e+01
#      9572           9865        4.0105e+02      2.92e-02       2.07e-03       2.68e+01
#      9573           9866        4.0103e+02      2.87e-02       2.07e-03       2.73e+01
#      9574           9867        4.0100e+02      2.92e-02       2.07e-03       2.68e+01
#      9575           9868        4.0097e+02      2.87e-02       2.07e-03       2.73e+01
#      9576           9869        4.0094e+02      2.91e-02       2.07e-03       2.68e+01
#      9577           9870        4.0091e+02      2.87e-02       2.07e-03       2.73e+01
#      9578           9871        4.0088e+02      2.91e-02       2.07e-03       2.68e+01
#      9579           9872        4.0085e+02      2.87e-02       2.07e-03       2.74e+01
#      9580           9873        4.0082e+02      2.91e-02       2.07e-03       2.68e+01
#      9581           9874        4.0079e+02      2.87e-02       2.07e-03       2.74e+01
#      9582           9875        4.0077e+02      2.91e-02       2.07e-03       2.68e+01
#      9583           9876        4.0074e+02      2.87e-02       2.07e-03       2.74e+01
#      9584           9877        4.0071e+02      2.91e-02       2.07e-03       2.68e+01
#      9585           9878        4.0068e+02      2.86e-02       2.07e-03       2.74e+01
#      9586           9879        4.0065e+02      2.91e-02       2.07e-03       2.68e+01
#      9587           9880        4.0062e+02      2.86e-02       2.07e-03       2.74e+01
#      9588           9881        4.0059e+02      2.91e-02       2.07e-03       2.69e+01
#      9589           9882        4.0056e+02      2.86e-02       2.07e-03       2.74e+01
#      9590           9883        4.0053e+02      2.91e-02       2.07e-03       2.69e+01
#      9591           9884        4.0051e+02      2.86e-02       2.07e-03       2.74e+01
#      9592           9885        4.0048e+02      2.91e-02       2.07e-03       2.69e+01
#      9593           9886        4.0045e+02      2.86e-02       2.07e-03       2.74e+01
#      9594           9887        4.0042e+02      2.91e-02       2.07e-03       2.69e+01
#      9595           9888        4.0039e+02      2.86e-02       2.07e-03       2.74e+01
#      9596           9889        4.0036e+02      2.91e-02       2.07e-03       2.69e+01
#      9597           9890        4.0033e+02      2.86e-02       2.07e-03       2.74e+01
#      9598           9891        4.0030e+02      2.91e-02       2.07e-03       2.69e+01
#      9599           9892        4.0028e+02      2.86e-02       2.07e-03       2.74e+01
#      9600           9893        4.0025e+02      2.91e-02       2.07e-03       2.69e+01
#      9601           9894        4.0022e+02      2.86e-02       2.07e-03       2.74e+01
#      9602           9895        4.0019e+02      2.91e-02       2.07e-03       2.69e+01
#      9603           9896        4.0016e+02      2.86e-02       2.07e-03       2.75e+01
#      9604           9897        4.0013e+02      2.90e-02       2.07e-03       2.69e+01
#      9605           9898        4.0010e+02      2.86e-02       2.07e-03       2.75e+01
#      9606           9899        4.0007e+02      2.90e-02       2.07e-03       2.69e+01
#      9607           9900        4.0004e+02      2.86e-02       2.07e-03       2.75e+01
#      9608           9901        4.0002e+02      2.90e-02       2.07e-03       2.69e+01
#      9609           9902        3.9999e+02      2.86e-02       2.07e-03       2.75e+01
#      9610           9903        3.9996e+02      2.90e-02       2.07e-03       2.69e+01
#      9611           9904        3.9993e+02      2.86e-02       2.07e-03       2.75e+01
#      9612           9905        3.9990e+02      2.90e-02       2.07e-03       2.70e+01
#      9613           9906        3.9987e+02      2.85e-02       2.07e-03       2.75e+01
#      9614           9907        3.9984e+02      2.90e-02       2.07e-03       2.70e+01
#      9615           9908        3.9981e+02      2.85e-02       2.07e-03       2.75e+01
#      9616           9909        3.9979e+02      2.90e-02       2.07e-03       2.70e+01
#      9617           9910        3.9976e+02      2.85e-02       2.07e-03       2.75e+01
#      9618           9911        3.9973e+02      2.90e-02       2.07e-03       2.70e+01
#      9619           9912        3.9970e+02      2.85e-02       2.07e-03       2.75e+01
#      9620           9913        3.9967e+02      2.90e-02       2.07e-03       2.70e+01
#      9621           9914        3.9964e+02      2.85e-02       2.07e-03       2.75e+01
#      9622           9915        3.9961e+02      2.90e-02       2.07e-03       2.70e+01
#      9623           9916        3.9958e+02      2.85e-02       2.07e-03       2.75e+01
#      9624           9917        3.9956e+02      2.90e-02       2.07e-03       2.70e+01
#      9625           9918        3.9953e+02      2.85e-02       2.07e-03       2.76e+01
#      9626           9919        3.9950e+02      2.90e-02       2.07e-03       2.70e+01
#      9627           9920        3.9947e+02      2.85e-02       2.07e-03       2.76e+01
#      9628           9921        3.9944e+02      2.90e-02       2.07e-03       2.70e+01
#      9629           9922        3.9941e+02      2.85e-02       2.07e-03       2.76e+01
#      9630           9923        3.9938e+02      2.89e-02       2.07e-03       2.70e+01
#      9631           9924        3.9935e+02      2.85e-02       2.07e-03       2.76e+01
#      9632           9925        3.9933e+02      2.89e-02       2.07e-03       2.70e+01
#      9633           9926        3.9930e+02      2.85e-02       2.07e-03       2.76e+01
#      9634           9927        3.9927e+02      2.89e-02       2.07e-03       2.71e+01
#      9635           9928        3.9924e+02      2.85e-02       2.07e-03       2.76e+01
#      9636           9929        3.9921e+02      2.89e-02       2.07e-03       2.71e+01
#      9637           9930        3.9918e+02      2.85e-02       2.07e-03       2.76e+01
#      9638           9931        3.9915e+02      2.89e-02       2.07e-03       2.71e+01
#      9639           9932        3.9913e+02      2.84e-02       2.07e-03       2.76e+01
#      9640           9933        3.9910e+02      2.89e-02       2.07e-03       2.71e+01
#      9641           9934        3.9907e+02      2.84e-02       2.07e-03       2.76e+01
#      9642           9935        3.9904e+02      2.89e-02       2.07e-03       2.71e+01
#      9643           9936        3.9901e+02      2.84e-02       2.07e-03       2.76e+01
#      9644           9937        3.9898e+02      2.89e-02       2.07e-03       2.71e+01
#      9645           9938        3.9895e+02      2.84e-02       2.07e-03       2.76e+01
#      9646           9939        3.9892e+02      2.89e-02       2.07e-03       2.71e+01
#      9647           9940        3.9890e+02      2.84e-02       2.07e-03       2.76e+01
#      9648           9941        3.9887e+02      2.89e-02       2.07e-03       2.71e+01
#      9649           9942        3.9884e+02      2.84e-02       2.07e-03       2.77e+01
#      9650           9943        3.9881e+02      2.89e-02       2.07e-03       2.71e+01
#      9651           9944        3.9878e+02      2.84e-02       2.07e-03       2.77e+01
#      9652           9945        3.9875e+02      2.89e-02       2.07e-03       2.71e+01
#      9653           9946        3.9872e+02      2.84e-02       2.07e-03       2.77e+01
#      9654           9947        3.9870e+02      2.89e-02       2.07e-03       2.71e+01
#      9655           9948        3.9867e+02      2.84e-02       2.07e-03       2.77e+01
#      9656           9949        3.9864e+02      2.89e-02       2.07e-03       2.71e+01
#      9657           9950        3.9861e+02      2.84e-02       2.07e-03       2.77e+01
#      9658           9951        3.9858e+02      2.88e-02       2.07e-03       2.72e+01
#      9659           9952        3.9855e+02      2.84e-02       2.07e-03       2.77e+01
#      9660           9953        3.9852e+02      2.88e-02       2.07e-03       2.72e+01
#      9661           9954        3.9850e+02      2.84e-02       2.07e-03       2.77e+01
#      9662           9955        3.9847e+02      2.88e-02       2.07e-03       2.72e+01
#      9663           9956        3.9844e+02      2.84e-02       2.07e-03       2.77e+01
#      9664           9957        3.9841e+02      2.88e-02       2.07e-03       2.72e+01
#      9665           9958        3.9838e+02      2.83e-02       2.07e-03       2.77e+01
#      9666           9959        3.9835e+02      2.88e-02       2.07e-03       2.72e+01
#      9667           9960        3.9832e+02      2.83e-02       2.07e-03       2.77e+01
#      9668           9961        3.9830e+02      2.88e-02       2.07e-03       2.72e+01
#      9669           9962        3.9827e+02      2.83e-02       2.07e-03       2.77e+01
#      9670           9963        3.9824e+02      2.88e-02       2.07e-03       2.72e+01
#      9671           9964        3.9821e+02      2.83e-02       2.07e-03       2.78e+01
#      9672           9965        3.9818e+02      2.88e-02       2.07e-03       2.72e+01
#      9673           9966        3.9815e+02      2.83e-02       2.07e-03       2.78e+01
#      9674           9967        3.9812e+02      2.88e-02       2.07e-03       2.72e+01
#      9675           9968        3.9810e+02      2.83e-02       2.07e-03       2.78e+01
#      9676           9969        3.9807e+02      2.88e-02       2.07e-03       2.72e+01
#      9677           9970        3.9804e+02      2.83e-02       2.07e-03       2.78e+01
#      9678           9971        3.9801e+02      2.88e-02       2.07e-03       2.72e+01
#      9679           9972        3.9798e+02      2.83e-02       2.07e-03       2.78e+01
#      9680           9973        3.9795e+02      2.88e-02       2.07e-03       2.72e+01
#      9681           9974        3.9792e+02      2.83e-02       2.07e-03       2.78e+01
#      9682           9975        3.9790e+02      2.88e-02       2.07e-03       2.73e+01
#      9683           9976        3.9787e+02      2.83e-02       2.07e-03       2.78e+01
#      9684           9977        3.9784e+02      2.88e-02       2.07e-03       2.73e+01
#      9685           9978        3.9781e+02      2.83e-02       2.07e-03       2.78e+01
#      9686           9979        3.9778e+02      2.87e-02       2.07e-03       2.73e+01
#      9687           9980        3.9775e+02      2.83e-02       2.07e-03       2.78e+01
#      9688           9981        3.9772e+02      2.87e-02       2.07e-03       2.73e+01
#      9689           9982        3.9770e+02      2.83e-02       2.07e-03       2.78e+01
#      9690           9983        3.9767e+02      2.87e-02       2.07e-03       2.73e+01
#      9691           9984        3.9764e+02      2.82e-02       2.07e-03       2.78e+01
#      9692           9985        3.9761e+02      2.87e-02       2.07e-03       2.73e+01
#      9693           9986        3.9758e+02      2.82e-02       2.07e-03       2.79e+01
#      9694           9987        3.9755e+02      2.87e-02       2.07e-03       2.73e+01
#      9695           9988        3.9753e+02      2.82e-02       2.07e-03       2.79e+01
#      9696           9989        3.9750e+02      2.87e-02       2.07e-03       2.73e+01
#      9697           9990        3.9747e+02      2.82e-02       2.07e-03       2.79e+01
#      9698           9991        3.9744e+02      2.87e-02       2.07e-03       2.73e+01
#      9699           9992        3.9741e+02      2.82e-02       2.07e-03       2.79e+01
#      9700           9993        3.9738e+02      2.87e-02       2.07e-03       2.73e+01
#      9701           9994        3.9735e+02      2.82e-02       2.07e-03       2.79e+01
#      9702           9995        3.9733e+02      2.87e-02       2.07e-03       2.73e+01
#      9703           9996        3.9730e+02      2.82e-02       2.07e-03       2.79e+01
#      9704           9997        3.9727e+02      2.87e-02       2.07e-03       2.74e+01
#      9705           9998        3.9724e+02      2.82e-02       2.07e-03       2.79e+01
#      9706           9999        3.9721e+02      2.87e-02       2.07e-03       2.74e+01
#      9707           10000       3.9718e+02      2.82e-02       2.07e-03       2.79e+01
# The maximum number of function evaluations is exceeded.
# Function evaluations 10000, initial cost 1.0250e+05, final cost 3.9718e+02, first-order optimality 2.79e+01.
# R11 = 18.578669;
# R12 = 9.646766;
# R13 = 9.887080;
# R14 = 10.156772;
# R15 = 11.844705;
# R16 = 10.584085;
#
# R21 = 9.831927;
# R22 = 20.900919;
# R23 = 12.955297;
# R24 = 10.831821;
# R25 = 10.001258;
# R26 = 9.573192;
#
# R31 = 12.124968;
# R32 = 13.638320;
# R33 = 24.126271;
# R34 = 15.573907;
# R35 = 14.068264;
# R36 = 11.088709;
#
# R41 = 10.287201;
# R42 = 10.911908;
# R43 = 15.048560;
# R44 = 20.258625;
# R45 = 13.204560;
# R46 = 9.612527;
#
# R51 = 11.180037;
# R52 = 11.037749;
# R53 = 14.796341;
# R54 = 13.706358;
# R55 = 20.461823;
# R56 = 9.876301;
#
# R61 = 10.079637;
# R62 = 8.835427;
# R63 = 8.100982;
# R64 = 7.675117;
# R65 = 8.190523;
# R66 = 17.181930;
#
# K11 = 0.780070;
# K12 = 0.099147;
# K13 = 0.008031;
# K14 = 0.093593;
# K15 = 0.149321;
# K16 = 0.116252;
#
# K21 = 0.061553;
# K22 = 0.676642;
# K23 = 0.205059;
# K24 = 0.053641;
# K25 = 0.003288;
# K26 = 0.124754;
#
# K31 = 0.017022;
# K32 = 0.044730;
# K33 = 0.642649;
# K34 = 0.180803;
# K35 = 0.026989;
# K36 = 0.014454;
#
# K41 = 0.010650;
# K42 = 0.029581;
# K43 = 0.175315;
# K44 = 0.763746;
# K45 = 0.237982;
# K46 = 0.012504;
#
# K51 = 0.257068;
# K52 = 0.015019;
# K53 = 0.032703;
# K54 = 0.090711;
# K55 = 0.706642;
# K56 = 0.013319;
#
# K61 = 0.281558;
# K62 = 0.307048;
# K63 = 0.050097;
# K64 = 0.401379;
# K65 = 0.096227;
# K66 = 0.921032;
#
#
# --- 420.584 seconds ---
#
# Saved parameters to param.xlsx
